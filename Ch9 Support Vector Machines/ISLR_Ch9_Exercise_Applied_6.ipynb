# %% [markdown]
# # Soal 6
#
# 1. [Buat data dengan dua kelas yang datanya terpisah secara linear](#1)
# 2. [Hitung cross-validationnya, berapa training errornya](#2)
# 3. [Buat test error dataset dan cari test error ratenya](#3)
# 4. [Berikan komentar terhadap hasilnya](#4)

# %% [markdown]
# ## 1

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.svm import SVC
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_val_score
from sklearn.datasets import make_classification

# %matplotlib inline

# %%
X, Y = make_classification(n_samples=500, n_features=2, n_redundant=0, n_informative=2, n_clusters_per_class=1, random_state=0)

# %%
plt.scatter(X[:,0], X[:,1], s=25, c=Y, cmap=plt.cm.Paired)
plt.xlabel('X1')
plt.ylabel('X2')
# Out:
# Text(0, 0.5, 'X2')

# %% [markdown]
# [kembali ke atas](#Soal-6)

# %% [markdown]
# ## 2

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=.3, random_state=1)

# %%
cost_range = [0.01, .1, 1, 10]
for i in cost_range:
    svc = SVC(kernel='linear', C=i, random_state=1)
    svc.fit(X_train, Y_train)
    print('\ni = ', i)
    print('%.3f' % (np.average(1-cross_val_score(svc, X, Y, cv=5, scoring='accuracy'))))
# Out:
# i =  0.01
# 0.140
#
# i =  0.1
# 0.122
#
# i =  1
# 0.126
#
# i =  10
# 0.124

# %%
for i in cost_range:
    svc = SVC(kernel='linear', C=i, random_state=1)
    svc.fit(X_train, Y_train)
    print('\ni =', i)
    print('Confusion matrix: ', confusion_matrix(Y_train, svc.predict(X_train)))
# Out:
# i = 0.01
# Confusion matrix:  [[153  23]
#  [ 27 147]]
#
# i = 0.1
# Confusion matrix:  [[167   9]
#  [ 32 142]]
#
# i = 1
# Confusion matrix:  [[163  13]
#  [ 31 143]]
#
# i = 10
# Confusion matrix:  [[162  14]
#  [ 31 143]]

# %% [markdown]
# [kembali ke atas](#Soal-6)

# %% [markdown]
# ## 3

# %%
X, Y = make_classification(n_samples=500, random_state=1)

# %%
plt.scatter(X[:,0], X[:,1], s=25, c=Y, cmap=plt.cm.Paired)
plt.xlabel('X1')
plt.ylabel('X2')
# Out:
# Text(0, 0.5, 'X2')

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=.3, random_state=1)

# %%
for i in cost_range:
    svc = SVC(kernel='linear', C=i, random_state=1)
    svc.fit(X_train, Y_train)
    print('\ni: ', i)
    print('Test error: ', 1-accuracy_score(Y_test, svc.predict(X_test)))
# Out:
# i:  0.01
# Test error:  0.1333333333333333
#
# i:  0.1
# Test error:  0.1466666666666666
#
# i:  1
# Test error:  0.1333333333333333
#
# i:  10
# Test error:  0.1333333333333333

# %%
for i in cost_range:
    svc = SVC(kernel='linear', C=i, random_state=1)
    svc.fit(X_train, Y_train)
    print('\ni: ', i)
    print('Training error: ', 1-accuracy_score(Y_train, svc.predict(X_train)))
# Out:
# i:  0.01
# Training error:  0.1428571428571429
#
# i:  0.1
# Training error:  0.1171428571428571
#
# i:  1
# Training error:  0.12571428571428567
#
# i:  10
# Training error:  0.12857142857142856

# %% [markdown]
# [kembali ke atas](#Soal-6)

# %% [markdown]
# ## 4

# %% [markdown]
# [kembali ke atas](#Soal-6)
